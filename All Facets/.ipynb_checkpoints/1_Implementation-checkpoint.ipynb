# %% [raw]
# !pip install -U plotly

# %% [raw]
# import sys
# !{sys.executable} -m pip install plotly

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import string
import sklearn

import nltk
from nltk import pos_tag, pos_tag_sents
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) - set(['at', 'do', 'your', 'from', 'to', 'out', 'no', 'the'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
path = '/home/manikya_varshney/Documents/Python/Yale/All Facets/final(Analysis)_h01-20200912-101538.csv'
data = pd.read_csv(path, low_memory=False)

# %% [raw]
# stay at home
# do your part
# Responsible
# home
# house
# cancel
# shutdown
# postpone
# school closure
# Closure
# business closure
# suspension
# quarantine
# lockdown
# social distance
# social distancing
# self quarantine
# isolat
# 6-feet
# distance
# #clubquarantine
# #quarantinelife
# #quarantineacitivites

# %%
keywords = ['stay at home' , 'do your part', 'Responsible', 
            'home', 'house', 'cancel', 'shutdown', 'postpone',
            'school closure', 'Closure', 'business closure',
            'suspension', 'quarantine', 'lockdown', 'social distance', 
            'social distancing', 'self quarantine', 'isolat', '6-feet',
            'distance', '#clubquarantine', '#quarantinelife', '#quarantineacitivites']

# %% [markdown]
# ##### 1. Casing (Upper or lower case)
# ##### 2. Noise Removal (Removal of punctuation, white spaces, special characters, HTML tags)
# ##### 3. Tokenization (Tweets to tokens i.e. words seprated by spaces)
# ##### 4. Stopword Removal
# ##### 5. Text Normalization (Stemming and Lemmatization)

# %%
#Convert to lower
for i in range(len(keywords)): 
    keywords[i] = keywords[i].lower()

#Remove punctuations   
for i in range(len(keywords)): 
    keywords[i] = keywords[i].translate(str.maketrans('','',string.punctuation))

#More cleaning
for i in range(len(keywords)): 
    keywords[i] = keywords[i].replace('/[^a-zA-Z0-9 ]/g', '').replace('\n',' ').strip('“').strip('“').strip('’').lstrip(' ').rstrip(' ')

#Tokenize
#keywords_tokens = [sub.split() for sub in keywords] 

#Remove stop words
def remove_stopwords(data):
    output_array=[]
    for sentence in data:
        temp_list=[]
        for word in sentence.split():
            if word not in stop_words:
                temp_list.append(word)
        output_array.append(' '.join(temp_list))
    return output_array

keywords_filtered=remove_stopwords(keywords)

#Stemming
ps = PorterStemmer()
keywords_stem = [[ps.stem(word) for word in sentence.split(" ")] for sentence in keywords_filtered]
keywords_stem = [" ".join(sentence) for sentence in keywords_stem]

#Lemmetizing

#POSTags
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

lemmatizer = WordNetLemmatizer()
keywords_lem = [[lemmatizer.lemmatize(y, get_wordnet_pos(y)) for y in sentence.split(" ")] for sentence in keywords_filtered]
keywords_final = [" ".join(sentence) for sentence in keywords_lem]

# %% [markdown]
# ## Fuzzy Matching

# %%
data['final'] = data['final'].apply(str)
choices = data['final'].tolist()

# %%
 def fuzzy_m(row):
        keyword_match, score = process.extractOne(row['final'], keywords_final, scorer = fuzz.partial_ratio)
        row['final_score'] = score
        row['final_keyword_match'] = keyword_match
        return row

# %%
interim_imp = data.apply(fuzzy_m, axis=1)

# %%
interim_imp
# Out:
#                 id       user_id  \
# 0     1.304786e+18  9.053900e+07
# 1     1.304786e+18  8.497239e+17
# 2     1.304786e+18  1.293830e+18
# 3     1.304786e+18  1.188902e+18
# 4     1.304786e+18  2.273830e+08
# ...            ...           ...
# 6732  1.304427e+18  6.874206e+07
# 6733  1.304671e+18  8.323244e+17
# 6734  1.304768e+18  4.446656e+09
# 6735  1.301853e+18  3.914277e+08
# 6736  1.304756e+18  2.215891e+09
#
#                                extended_tweet_full_text  \
# 0     woke up to see if the justin bieber pandemic w...
# 1     our intention is to make sure that evidence sc...
# 2     for more information contact us  mail  follow ...
# 3     uae reports 1007 new covid19 cases highest sin...
# 4     trump officials interfered with cdc reports on...
# ...                                                 ...
# 6732  why did twitter suddenly reinstate   could it ...
# 6733  denna veckas covid19 veckorapport från folkhäl...
# 6734  republicans defend trump after he admitted dow...
# 6735  the recession on the back of the governments h...
# 6736  65 catholics across the street only 7 wearing ...
#
#                      extended_tweet_full_text_duplicate  \
# 0     woke up to see if the justin bieber pandemic w...
# 1     @TeresaCCarter2 “Our intention is to make sure...
# 2     For More Information contact us. \nMail:- digi...
# 3     UAE reports 1,007 new Covid-19 cases, highest ...
# 4     Trump officials interfered with CDC reports on...
# ...                                                 ...
# 6732  Why did Twitter suddenly reinstate @clif_high?...
# 6733  Denna veckas COVID-19 veckorapport från Folkhä...
# 6734  Republicans Defend Trump After He Admitted Dow...
# 6735  The recession on the back of the Government's ...
# 6736  65 Catholics across the street only 7 wearing ...
#
#                                                   final  final_score  \
# 0     woke to see the justin bieber pandemic go back...           60
# 1      intention to make sure evidence sciencebased ...           50
# 2     information contact u mail follow instagram gy...           62
# 3     uae report 1007 new covid19 case high since ou...           57
# 4     trump official interfere cdc report covid19 po...           60
# ...                                                 ...          ...
# 6732  twitter suddenly reinstate could science valid...           62
# 6733  denna veckas covid19 veckorapport från folkhäl...           60
# 6734  republican defend trump admit downplay true th...           67
# 6735  the recession the back the government handle c...           53
# 6736          65 catholic across the street 7 wear mask           60
#
#      final_keyword_match
# 0                  6feet
# 1           stay at home
# 2               distance
# 3                closure
# 4        social distance
# ...                  ...
# 6732            distance
# 6733          suspension
# 6734              cancel
# 6735     social distance
# 6736               6feet
#
# [6737 rows x 7 columns]

# %%
interim_imp['final_score'] = interim_imp['final_score'].astype(int)

# %%
interim_imp = interim_imp[interim_imp['final_score'] == 100]

# %%
interim_imp
# Out:
#                 id       user_id  \
# 9     1.304786e+18  5.825632e+07
# 16    1.304786e+18  4.200751e+07
# 21    1.304786e+18  8.185423e+07
# 30    1.304786e+18  4.231834e+09
# 33    1.304786e+18  1.296229e+18
# ...            ...           ...
# 6677  1.304546e+18  2.648717e+07
# 6685  1.263393e+18  7.940104e+08
# 6710  1.304685e+18  3.178464e+09
# 6718  1.304026e+18  1.427513e+07
# 6726  1.301605e+18  1.939794e+07
#
#                                extended_tweet_full_text  \
# 9     coronavirus isolation rulebreakers in england ...
# 16    lockdown day 173  see my new daily photo on bl...
# 21    an amesbury woman has been named a lockdown he...
# 30    recommended read  whats more the coronavirus i...
# 33    truthfully i took it out earlier in quarantine...
# ...                                                 ...
# 6677  politicizing the pandemic  slams the left’s ca...
# 6685  the communities who are going to be scared aft...
# 6710  tanoa had the cops called on them after being ...
# 6718  dont jump to conclusions about the oxford vacc...
# 6726  i’ve consistently called on the government to ...
#
#                      extended_tweet_full_text_duplicate  \
# 9     Coronavirus: isolation rule-breakers in Englan...
# 16    "Lockdown Day 173" https://t.co/MdPkYSfNo2  Se...
# 21    An Amesbury woman has been named a 'lockdown h...
# 30    Recommended read - What's more, the coronaviru...
# 33    truthfully I took it out earlier in quarantine...
# ...                                                 ...
# 6677  Politicizing the Pandemic: @AlexBerenson slams...
# 6685  The communities who are going to be scared aft...
# 6710  Tanoa had the cops called on them after being ...
# 6718  Don't jump to conclusions about the Oxford vac...
# 6726  I’ve consistently called on the Government to ...
#
#                                                   final  final_score  \
# 9     coronavirus isolation rulebreakers england may...          100
# 16        lockdown day 173 see new daily photo blipfoto          100
# 21    amesbury woman name lockdown hero to great wes...          100
# 30    recommend read whats the coronavirus sweep acr...          100
# 33    truthfully take out earlier quarantine  consid...          100
# ...                                                 ...          ...
# 6677  politicize the pandemic slam the left  call se...          100
# 6685  the community go to scar lockdown lift the one...          100
# 6710  tanoa the cop call give the green light to ope...          100
# 6718  dont jump to conclusion the oxford vaccine tri...          100
# 6726   consistently call the government to deliver w...          100
#
#      final_keyword_match
# 9                 isolat
# 16              lockdown
# 21              lockdown
# 30              lockdown
# 33            quarantine
# ...                  ...
# 6677            lockdown
# 6685            lockdown
# 6710            shutdown
# 6718          suspension
# 6726              isolat
#
# [958 rows x 7 columns]

# %%
interim_imp[interim_imp['final_score'] == 100].to_csv('interim_imp.csv',index=False)
