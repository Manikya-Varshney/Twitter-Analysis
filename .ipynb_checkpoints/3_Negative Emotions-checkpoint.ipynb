# %% [raw]
# !pip install -U python-Levenshtein

# %% [raw]
# import sys
# !{sys.executable} -m pip install python-Levenshtein

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import string

import nltk
from nltk import pos_tag, pos_tag_sents
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
path = '/home/manikya_varshney/Documents/Python/Yale/final_processed_h01-20200912-101538.csv'
data = pd.read_csv(path, low_memory=False)

# %% [raw]
# bored
# lonely
# stress
# anxiety
# scared
# worry
# end
# cabin fever
# #sideeffectsofquarantinelife
# tissue paper
# toilet paper

# %%
keywords = ['bored' , 'lonely', 'stress', 
            'anxiety', 'scared', 'worry', 'end', 'cabin fever',
            '#sideeffectsofquarantinelife', 'tissue paper', 'toilet paper']

# %% [markdown]
# ##### 1. Casing (Upper or lower case)
# ##### 2. Noise Removal (Removal of punctuation, white spaces, special characters, HTML tags)
# ##### 3. Tokenization (Tweets to tokens i.e. words seprated by spaces)
# ##### 4. Stopword Removal
# ##### 5. Text Normalization (Stemming and Lemmatization)

# %%
#Convert to lower
for i in range(len(keywords)): 
    keywords[i] = keywords[i].lower()

#Remove punctuations   
for i in range(len(keywords)): 
    keywords[i] = keywords[i].translate(str.maketrans('','',string.punctuation))

#More cleaning
for i in range(len(keywords)): 
    keywords[i] = keywords[i].replace('/[^a-zA-Z0-9 ]/g', '').replace('\n',' ').strip('“').strip('“').strip('’').lstrip(' ').rstrip(' ')

#Tokenize
#keywords_tokens = [sub.split() for sub in keywords] 

#Remove stop words
def remove_stopwords(data):
    output_array=[]
    for sentence in data:
        temp_list=[]
        for word in sentence.split():
            if word not in stop_words:
                temp_list.append(word)
        output_array.append(' '.join(temp_list))
    return output_array

keywords_filtered=remove_stopwords(keywords)

#Stemming
ps = PorterStemmer()
keywords_stem = [[ps.stem(word) for word in sentence.split(" ")] for sentence in keywords_filtered]
keywords_stem = [" ".join(sentence) for sentence in keywords_stem]

#Lemmetizing

#POSTags
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

lemmatizer = WordNetLemmatizer()
keywords_lem = [[lemmatizer.lemmatize(y, get_wordnet_pos(y)) for y in sentence.split(" ")] for sentence in keywords_filtered]
keywords_final = [" ".join(sentence) for sentence in keywords_lem]

# %% [markdown]
# ## Fuzzy Matching

# %%
data['final'] = data['final'].apply(str)
choices = data['final'].tolist()

# %% [raw]
# def fuzzy_m(row):
#     matches = process.extract(row['final'], keywords_final, limit=3)
#     exactMatch = matches[0][1] == 90
#     row['Match 1'] = matches[0][0]
#     row['Match 1 Score'] = matches[0][1]
#     row['Match 2'] = "" if exactMatch else matches[1][0]
#     row['Match 2 Score'] = "" if exactMatch else matches[1][1]
#     row['Match 3'] = "" if exactMatch else matches[2][0]
#     row['Match 3 Score'] = "" if exactMatch else matches[2][1]
#     return row

# %% [raw]
# interim_ne = data.apply(fuzzy_m, axis=1)

# %% [raw]
# interim_ne

# %% [raw]
# interim_ne['Match 1 Score'] = interim_ne['Match 1 Score'].astype(int)

# %% [raw]
# interim_ne[interim_ne['Match 1 Score'] == 90].count()

# %% [markdown]
# # Testing

# %%
 def fuzzy_m(row):
        keyword_match, score = process.extractOne(row['final'], keywords_final, scorer = fuzz.partial_ratio)
        row['final_score'] = score
        row['final_keyword_match'] = keyword_match
        return row

# %%
interim_ne = data.apply(fuzzy_m, axis=1)

# %%
interim_ne
# Out:
#                 id       user_id  \
# 0     1.304786e+18  9.053900e+07
# 1     1.304786e+18  8.497239e+17
# 2     1.304786e+18  1.293830e+18
# 3     1.304786e+18  1.188902e+18
# 4     1.304786e+18  2.273830e+08
# ...            ...           ...
# 6732  1.304427e+18  6.874206e+07
# 6733  1.304671e+18  8.323244e+17
# 6734  1.304768e+18  4.446656e+09
# 6735  1.301853e+18  3.914277e+08
# 6736  1.304756e+18  2.215891e+09
#
#                                extended_tweet_full_text  \
# 0     woke up to see if the justin bieber pandemic w...
# 1     our intention is to make sure that evidence sc...
# 2     for more information contact us  mail  follow ...
# 3     uae reports 1007 new covid19 cases highest sin...
# 4     trump officials interfered with cdc reports on...
# ...                                                 ...
# 6732  why did twitter suddenly reinstate   could it ...
# 6733  denna veckas covid19 veckorapport från folkhäl...
# 6734  republicans defend trump after he admitted dow...
# 6735  the recession on the back of the governments h...
# 6736  65 catholics across the street only 7 wearing ...
#
#                      extended_tweet_full_text_duplicate  \
# 0     woke up to see if the justin bieber pandemic w...
# 1     @TeresaCCarter2 “Our intention is to make sure...
# 2     For More Information contact us. \nMail:- digi...
# 3     UAE reports 1,007 new Covid-19 cases, highest ...
# 4     Trump officials interfered with CDC reports on...
# ...                                                 ...
# 6732  Why did Twitter suddenly reinstate @clif_high?...
# 6733  Denna veckas COVID-19 veckorapport från Folkhä...
# 6734  Republicans Defend Trump After He Admitted Dow...
# 6735  The recession on the back of the Government's ...
# 6736  65 Catholics across the street only 7 wearing ...
#
#                                                   final  final_score  \
# 0         woke see justin bieber pandemic go back sleep           67
# 1      intention make sure evidence sciencebased dat...           67
# 2     information contact u mail follow instagram gy...           67
# 3     uae report 1007 new covid19 case high since ou...           50
# 4     trump official interfere cdc report covid19 po...           55
# ...                                                 ...          ...
# 6732  twitter suddenly reinstate could science valid...           67
# 6733  denna veckas covid19 veckorapport från folkhäl...           83
# 6734  republican defend trump admit downplay true th...           67
# 6735  recession back government handle covid economi...           67
# 6736              65 catholic across street 7 wear mask           67
#
#      final_keyword_match
# 0                    end
# 1                    end
# 2                 stress
# 3                   bore
# 4            cabin fever
# ...                  ...
# 6732                 end
# 6733              stress
# 6734                 end
# 6735                 end
# 6736              stress
#
# [6737 rows x 7 columns]

# %%
interim_ne['final_score'] = interim_ne['final_score'].astype(int)

# %%
interim_ne[interim_ne['final_score'] == 100]
# Out:
#                 id       user_id  \
# 10    1.304786e+18  1.108805e+18
# 15    1.304786e+18  1.270821e+18
# 30    1.304786e+18  4.231834e+09
# 100   1.304786e+18  1.193239e+09
# 109   1.304786e+18  1.293297e+18
# ...            ...           ...
# 6675  1.304373e+18  1.181489e+18
# 6683  1.304562e+18  4.848211e+08
# 6685  1.263393e+18  7.940104e+08
# 6695  1.304506e+18  3.577304e+07
# 6707  1.304489e+18  1.417332e+07
#
#                                extended_tweet_full_text  \
# 10    people on the team are definitely testing posi...
# 15    i miss my mf bestfriends  bts ima see u soon d...
# 30    recommended read  whats more the coronavirus i...
# 100   i tend to tip at a much higher  now than i did...
# 109   after the toilet paper shortage trump as our l...
# ...                                                 ...
# 6675  d lng nmn po kc sa na eexpose cla e’ bka may n...
# 6683  urgent weekend update temporary testing centre...
# 6685  the communities who are going to be scared aft...
# 6695  as covid19 has transformed the way that americ...
# 6707  dr fauci but by the time you mobilize the dist...
#
#                      extended_tweet_full_text_duplicate  \
# 10    @Ruebush77 @LazeVT People on the team are defi...
# 15    i miss my mf bestfriends )): bts ima see u soo...
# 30    Recommended read - What's more, the coronaviru...
# 100   @greta I tend to tip at a much higher % now th...
# 109   @HaroldFordJr @FoxNews @BretBaier @SpecialRepo...
# ...                                                 ...
# 6675  @chard_maine2016 @aldenrichards02 @mainedcm D ...
# 6683  ❗️URGENT WEEKEND UPDATE- Temporary Testing Cen...
# 6685  The communities who are going to be scared aft...
# 6695  “As COVID-19 has transformed the way that Amer...
# 6707  Dr. Fauci: "But by the time you mobilize the d...
#
#                                                   final  final_score  \
# 10    people team definitely test positive read fuen...          100
# 15    miss mf bestfriends bts ima see u soon  worry ...          100
# 30    recommend read whats coronavirus sweep across ...          100
# 100   tend tip much high covid19 struck ive always g...          100
# 109   toilet paper shortage trump leader right keep ...          100
# ...                                                 ...          ...
# 6675  lng nmn po kc sa na eexpose cla e  bka may nka...          100
# 6683  urgent weekend update temporary test centre rc...          100
# 6685  community go scar lockdown lift one shield cor...          100
# 6695  covid19 transform way american live threatens ...          100
# 6707  dr fauci time mobilize distribution vaccine ge...          100
#
#      final_keyword_match
# 10                   end
# 15                 worry
# 30                   end
# 100                  end
# 109         toilet paper
# ...                  ...
# 6675                 end
# 6683                 end
# 6685                scar
# 6695                 end
# 6707                 end
#
# [340 rows x 7 columns]

# %%
interim_ne.to_csv('interim_ne.csv',index=False)
