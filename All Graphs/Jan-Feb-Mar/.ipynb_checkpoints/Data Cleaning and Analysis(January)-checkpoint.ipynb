# %%
import pandas as pd
import numpy as np 
import csv
import re
import string
import datetime
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

import warnings
warnings.filterwarnings("ignore")

# %%
path = '/home/manikya_varshney/Documents/Python/Yale/All Graphs/Jan-Feb-Mar/Jan-Feb-Mar-Data/January/(Final)January.csv'
data = pd.read_csv(path, low_memory=False)

# %%
cols = [0, 1, 2, 4, 10, 11, 29, 30, 31, 36]

# %%
data = data[data.columns.values[cols]]

# %%
data
# Out:
#                    user_id            status_id           created_at  \
# 0       740588957797220352  1220051216081788929  2020-01-22 18:30:52
# 1               1971510733  1220057558033014784  2020-01-22 18:56:04
# 2               2419585452  1220059356697452546  2020-01-22 19:03:12
# 3                 14413869  1220059703104815104  2020-01-22 19:04:35
# 4               1601210089  1220061420890607617  2020-01-22 19:11:25
# ...                    ...                  ...                  ...
# 11312            807359047  1223394406503501824  2020-01-31 23:55:30
# 11313  1044064694103760896  1223394449490726912  2020-01-31 23:55:40
# 11314   911735284533886976  1223394489617641472  2020-01-31 23:55:50
# 11315   993914504206483457  1223394886960975872  2020-01-31 23:57:25
# 11316           2269486316  1223394936042618880  2020-01-31 23:57:36
#
#                                                     text is_quote is_retweet  \
# 0      lysoling da fuck outta everything bc i aint ca...    False      False
# 1                  1 Coronavirus confirmed in Washington    False      False
# 2      Hmmmmm, could the #coronavirus soon be the new...    False      False
# 3      At 11 million people, #Wuhan is larger than Ne...    False      False
# 4      Wuhan is cutting off inflows and outflows of t...    False      False
# ...                                                  ...      ...        ...
# 11312  Nice to know, now that CNN has lost the impeac...     True      False
# 11313  Italy declares state of emergency over coronav...    False      False
# 11314  Enjoy the game. Please don't get on the plane ...    False      False
# 11315  Coronavirus = Instagram mask marketing https:/...    False      False
# 11316  Airlines stop flights to China due to coronavi...    False      False
#
#       lang  quoted_status_id  \
# 0       en               NaN
# 1       en               NaN
# 2       en               NaN
# 3       en               NaN
# 4       en               NaN
# ...    ...               ...
# 11312   en      1.222965e+18
# 11313   en               NaN
# 11314   en               NaN
# 11315   en               NaN
# 11316   en               NaN
#
#                                              quoted_text  quoted_user_id
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                                    NaN             NaN
# 3                                                    NaN             NaN
# 4                                                    NaN             NaN
# ...                                                  ...             ...
# 11312  Coronavirus task force another example of Trum...      13850422.0
# 11313                                                NaN             NaN
# 11314                                                NaN             NaN
# 11315                                                NaN             NaN
# 11316                                                NaN             NaN
#
# [11317 rows x 10 columns]

# %%
data['lang'].value_counts()
# Out:
# en    11313
# Name: lang, dtype: int64

# %%
data = data[data['lang'] == 'en'].reset_index(drop=True)

# %% [markdown]
# # Date Sorting

# %% [raw]
# pd.to_datetime(data['created_at']).dt.date == pd.Timestamp(2020,1,22)

# %%
data['Date_Flag'] = data['created_at'].str[:10] == '2020-01-22'

# %%
data['Date_Flag'].value_counts()
# Out:
# False    11241
# True        72
# Name: Date_Flag, dtype: int64

# %%
data
# Out:
#                    user_id            status_id           created_at  \
# 0       740588957797220352  1220051216081788929  2020-01-22 18:30:52
# 1               1971510733  1220057558033014784  2020-01-22 18:56:04
# 2               2419585452  1220059356697452546  2020-01-22 19:03:12
# 3                 14413869  1220059703104815104  2020-01-22 19:04:35
# 4               1601210089  1220061420890607617  2020-01-22 19:11:25
# ...                    ...                  ...                  ...
# 11308            807359047  1223394406503501824  2020-01-31 23:55:30
# 11309  1044064694103760896  1223394449490726912  2020-01-31 23:55:40
# 11310   911735284533886976  1223394489617641472  2020-01-31 23:55:50
# 11311   993914504206483457  1223394886960975872  2020-01-31 23:57:25
# 11312           2269486316  1223394936042618880  2020-01-31 23:57:36
#
#                                                     text is_quote is_retweet  \
# 0      lysoling da fuck outta everything bc i aint ca...    False      False
# 1                  1 Coronavirus confirmed in Washington    False      False
# 2      Hmmmmm, could the #coronavirus soon be the new...    False      False
# 3      At 11 million people, #Wuhan is larger than Ne...    False      False
# 4      Wuhan is cutting off inflows and outflows of t...    False      False
# ...                                                  ...      ...        ...
# 11308  Nice to know, now that CNN has lost the impeac...     True      False
# 11309  Italy declares state of emergency over coronav...    False      False
# 11310  Enjoy the game. Please don't get on the plane ...    False      False
# 11311  Coronavirus = Instagram mask marketing https:/...    False      False
# 11312  Airlines stop flights to China due to coronavi...    False      False
#
#       lang  quoted_status_id  \
# 0       en               NaN
# 1       en               NaN
# 2       en               NaN
# 3       en               NaN
# 4       en               NaN
# ...    ...               ...
# 11308   en      1.222965e+18
# 11309   en               NaN
# 11310   en               NaN
# 11311   en               NaN
# 11312   en               NaN
#
#                                              quoted_text  quoted_user_id  \
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                                    NaN             NaN
# 3                                                    NaN             NaN
# 4                                                    NaN             NaN
# ...                                                  ...             ...
# 11308  Coronavirus task force another example of Trum...      13850422.0
# 11309                                                NaN             NaN
# 11310                                                NaN             NaN
# 11311                                                NaN             NaN
# 11312                                                NaN             NaN
#
#        Date_Flag
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ...          ...
# 11308      False
# 11309      False
# 11310      False
# 11311      False
# 11312      False
#
# [11313 rows x 11 columns]

# %%
interim_date = data[np.where((data['Date_Flag'] == True),True,False)].reset_index(drop=True)

# %%
interim_date
# Out:
#                 user_id            status_id           created_at  \
# 0    740588957797220352  1220051216081788929  2020-01-22 18:30:52
# 1            1971510733  1220057558033014784  2020-01-22 18:56:04
# 2            2419585452  1220059356697452546  2020-01-22 19:03:12
# 3              14413869  1220059703104815104  2020-01-22 19:04:35
# 4            1601210089  1220061420890607617  2020-01-22 19:11:25
# ..                  ...                  ...                  ...
# 67            393733048  1220130862408372229  2020-01-22 23:47:21
# 68  1026223248260849664  1220131257251717122  2020-01-22 23:48:55
# 69            405626885  1220131463678570497  2020-01-22 23:49:44
# 70  1019503232190681088  1220131795192221696  2020-01-22 23:51:03
# 71            620689391  1220133743899209729  2020-01-22 23:58:48
#
#                                                  text is_quote is_retweet  \
# 0   lysoling da fuck outta everything bc i aint ca...    False      False
# 1               1 Coronavirus confirmed in Washington    False      False
# 2   Hmmmmm, could the #coronavirus soon be the new...    False      False
# 3   At 11 million people, #Wuhan is larger than Ne...    False      False
# 4   Wuhan is cutting off inflows and outflows of t...    False      False
# ..                                                ...      ...        ...
# 67  @L0gg0l The coronavirus seems pretty bad from ...    False      False
# 68  #BREAKING: Coronavirus Outbreak — #Wuhan, Chin...    False      False
# 69  And this is exactly how dangerous viruses spre...     True      False
# 70  Ummmm this takes #SnakeGate to a whole new lev...    False      False
# 71  Authorities limit the travel of 11 million res...    False      False
#
#    lang  quoted_status_id                                        quoted_text  \
# 0    en               NaN                                                NaN
# 1    en               NaN                                                NaN
# 2    en               NaN                                                NaN
# 3    en               NaN                                                NaN
# 4    en               NaN                                                NaN
# ..  ...               ...                                                ...
# 67   en               NaN                                                NaN
# 68   en               NaN                                                NaN
# 69   en      1.220126e+18  #Breaking: 21 students from Chinese province a...
# 70   en               NaN                                                NaN
# 71   en               NaN                                                NaN
#
#     quoted_user_id  Date_Flag
# 0              NaN       True
# 1              NaN       True
# 2              NaN       True
# 3              NaN       True
# 4              NaN       True
# ..             ...        ...
# 67             NaN       True
# 68             NaN       True
# 69     123406653.0       True
# 70             NaN       True
# 71             NaN       True
#
# [72 rows x 11 columns]

# %% [markdown]
# # Date Cleaning

# %% [markdown]
# ##### is_quote --> False

# %%
interim_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           72 non-null     object
#  1   status_id         72 non-null     object
#  2   created_at        72 non-null     object
#  3   text              72 non-null     object
#  4   is_quote          72 non-null     object
#  5   is_retweet        72 non-null     object
#  6   lang              72 non-null     object
#  7   quoted_status_id  10 non-null     float64
#  8   quoted_text       10 non-null     object
#  9   quoted_user_id    10 non-null     float64
#  10  Date_Flag         72 non-null     bool
# dtypes: bool(1), float64(2), object(8)
# memory usage: 5.8+ KB

# %%
interim = interim_date[np.where((interim_date['is_quote']== 'False' ),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (62, 11)

# %%
interim['status_id'].nunique()
# Out:
# 62

# %%
non_rep = interim[['user_id','text']]

# %% [markdown]
# ##### is_quote --> True

# %%
interim_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           72 non-null     object
#  1   status_id         72 non-null     object
#  2   created_at        72 non-null     object
#  3   text              72 non-null     object
#  4   is_quote          72 non-null     object
#  5   is_retweet        72 non-null     object
#  6   lang              72 non-null     object
#  7   quoted_status_id  10 non-null     float64
#  8   quoted_text       10 non-null     object
#  9   quoted_user_id    10 non-null     float64
#  10  Date_Flag         72 non-null     bool
# dtypes: bool(1), float64(2), object(8)
# memory usage: 5.8+ KB

# %%
interim = interim_date[np.where((interim_date['is_quote']== 'True'),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (10, 11)

# %%
interim = interim[['user_id','text']]

# %%
interim.columns = non_rep.columns

# %%
interim.shape
# Out:
# (10, 2)

# %%
non_rep = non_rep.append(interim,ignore_index=True)

# %%
non_rep.shape
# Out:
# (72, 2)

# %%
interim_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           72 non-null     object
#  1   status_id         72 non-null     object
#  2   created_at        72 non-null     object
#  3   text              72 non-null     object
#  4   is_quote          72 non-null     object
#  5   is_retweet        72 non-null     object
#  6   lang              72 non-null     object
#  7   quoted_status_id  10 non-null     float64
#  8   quoted_text       10 non-null     object
#  9   quoted_user_id    10 non-null     float64
#  10  Date_Flag         72 non-null     bool
# dtypes: bool(1), float64(2), object(8)
# memory usage: 5.8+ KB

# %%
interim = interim_date[np.where((interim_date['is_quote']== 'True'),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (10, 11)

# %%
interim[['quoted_text']]
# Out:
#                                          quoted_text
# 0  "No one wants to be the first in the nation in...
# 1  Officials in Wuhan, China, shut down the airpo...
# 2  A new virus has killed 17 people in China and ...
# 3  Mr. Peanut is dead. I know this because I read...
# 4  China has locked down a city of 11 million to ...
# 5  最新！#武汉肺炎 增至324例！病毒大面积蔓延各省！澳洲总理紧急发言！全澳航空拉响警报！国内...
# 6  NEWS: Grow Mobility, the scooter leader of Lat...
# 7  Memo also gives guidance to specimen collectio...
# 8  Caixin removed its paywall for all #WuhanCoron...
# 9  #Breaking: 21 students from Chinese province a...

# %%
interim = interim[['quoted_user_id','quoted_text']]

# %%
interim
# Out:
#    quoted_user_id                                        quoted_text
# 0    3.681780e+07  "No one wants to be the first in the nation in...
# 1    4.283330e+05  Officials in Wuhan, China, shut down the airpo...
# 2    7.421430e+05  A new virus has killed 17 people in China and ...
# 3    1.086439e+18  Mr. Peanut is dead. I know this because I read...
# 4    4.030324e+07  China has locked down a city of 11 million to ...
# 5    2.348554e+08  最新！#武汉肺炎 增至324例！病毒大面积蔓延各省！澳洲总理紧急发言！全澳航空拉响警报！国内...
# 6    1.983242e+08  NEWS: Grow Mobility, the scooter leader of Lat...
# 7    1.096420e+09  Memo also gives guidance to specimen collectio...
# 8    1.606213e+09  Caixin removed its paywall for all #WuhanCoron...
# 9    1.234067e+08  #Breaking: 21 students from Chinese province a...

# %%
interim = interim.rename(columns={'quoted_user_id':'user_id', 'quoted_text':'text'})

# %%
non_rep = non_rep.append(interim,ignore_index=True)

# %%
non_rep.shape
# Out:
# (82, 2)

# %%
non_rep
# Out:
#                user_id                                               text
# 0   740588957797220352  lysoling da fuck outta everything bc i aint ca...
# 1           1971510733              1 Coronavirus confirmed in Washington
# 2           2419585452  Hmmmmm, could the #coronavirus soon be the new...
# 3             14413869  At 11 million people, #Wuhan is larger than Ne...
# 4           1601210089  Wuhan is cutting off inflows and outflows of t...
# ..                 ...                                                ...
# 77         234855418.0  最新！#武汉肺炎 增至324例！病毒大面积蔓延各省！澳洲总理紧急发言！全澳航空拉响警报！国内...
# 78         198324177.0  NEWS: Grow Mobility, the scooter leader of Lat...
# 79        1096420230.0  Memo also gives guidance to specimen collectio...
# 80        1606212504.0  Caixin removed its paywall for all #WuhanCoron...
# 81         123406653.0  #Breaking: 21 students from Chinese province a...
#
# [82 rows x 2 columns]

# %% [markdown]
# # Analysis

# %%
import pandas as pd
import numpy as np 
import csv
import re
import string
import emoji

import nltk
from nltk import pos_tag, pos_tag_sents
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

import warnings
warnings.filterwarnings("ignore")

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
stop_words = set(stopwords.words('english')) - set(['at', 'do', 'your', 'from', 'to', 'out', 'no', 'the'])
#demoji.download_codes()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
non_rep['text_duplicate'] = non_rep['text']

# %%
non_rep
# Out:
#                user_id                                               text  \
# 0   740588957797220352  lysoling da fuck outta everything bc i aint ca...
# 1           1971510733              1 Coronavirus confirmed in Washington
# 2           2419585452  Hmmmmm, could the #coronavirus soon be the new...
# 3             14413869  At 11 million people, #Wuhan is larger than Ne...
# 4           1601210089  Wuhan is cutting off inflows and outflows of t...
# ..                 ...                                                ...
# 77         234855418.0  最新！#武汉肺炎 增至324例！病毒大面积蔓延各省！澳洲总理紧急发言！全澳航空拉响警报！国内...
# 78         198324177.0  NEWS: Grow Mobility, the scooter leader of Lat...
# 79        1096420230.0  Memo also gives guidance to specimen collectio...
# 80        1606212504.0  Caixin removed its paywall for all #WuhanCoron...
# 81         123406653.0  #Breaking: 21 students from Chinese province a...
#
#                                        text_duplicate
# 0   lysoling da fuck outta everything bc i aint ca...
# 1               1 Coronavirus confirmed in Washington
# 2   Hmmmmm, could the #coronavirus soon be the new...
# 3   At 11 million people, #Wuhan is larger than Ne...
# 4   Wuhan is cutting off inflows and outflows of t...
# ..                                                ...
# 77  最新！#武汉肺炎 增至324例！病毒大面积蔓延各省！澳洲总理紧急发言！全澳航空拉响警报！国内...
# 78  NEWS: Grow Mobility, the scooter leader of Lat...
# 79  Memo also gives guidance to specimen collectio...
# 80  Caixin removed its paywall for all #WuhanCoron...
# 81  #Breaking: 21 students from Chinese province a...
#
# [82 rows x 3 columns]

# %%
#Convert to lower case
non_rep['text'] = non_rep['text'].str.lower()

# %%
#Removing emojis
def demoji(text):
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U00010000-\U0010ffff"
                               "]+", flags=re.UNICODE)
    return(emoji_pattern.sub(r'', text))

non_rep[u'text'] = non_rep[u'text'].astype(str)
non_rep[u'text'] = non_rep[u'text'].apply(lambda x:demoji(x))

# %%
#Remove URLs
non_rep['text'] = non_rep['text'].str.replace(r"http\S+| www\S+| https\S+| \S+\.com\S+| \S+\.com", "", regex=True)

# %%
#Remove user @
non_rep['text'] = non_rep['text'].str.replace(r'\@[\w]+', "", regex=True)

# %%
#Remove punctuations
non_rep['text'] = non_rep['text'].str.translate(str.maketrans("", "", string.punctuation))

# %%
#More Cleaning
non_rep['text']=non_rep['text'].astype(str).str.replace('/[^a-zA-Z0-9 ]/g', '', regex=True).str.replace('\n',' ', regex=True).str.replace('—',' ', regex=True).str.strip('“').str.strip('”').str.strip('’').str.lstrip(' ').str.rstrip(' ')

# %%
#Tokenizing
non_rep.text = non_rep.text.astype(str)
non_rep['tokenized_text'] = non_rep.apply(lambda row: nltk.word_tokenize(row.text), axis=1)

# remove stopwords
non_rep['filtered_text'] = non_rep['tokenized_text'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
#Stemming
ps = PorterStemmer()
non_rep['stemmed_text'] = non_rep['filtered_text'].apply(lambda x: [ps.stem(y) for y in x])

# %%
#POSTags
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
#Lemmatizing
lemmatizer = WordNetLemmatizer()
non_rep['lemmatized_text'] = non_rep['filtered_text'].apply(lambda x: [lemmatizer.lemmatize(y, get_wordnet_pos(y)) for y in x])

# %%
#Joining the lemmetized tokens to form string
non_rep['final'] = non_rep['lemmatized_text'].apply(lambda x: " ".join([word for word in x]))

# %%
#Remove punctuations
non_rep['final'] = non_rep['final'].str.translate(str.maketrans("", "", string.punctuation))
non_rep['final'] = non_rep['final'].str.replace("’", '').str.replace("“", '').str.replace("”", '')
#non_rep['text'] = non_rep['text'].astype(str).str.replace('/[^a-zA-Z0-9 ]/g', '', regex=True).str.replace('\n',' ', regex=True).str.replace('—',' ', regex=True).str.strip('“').str.strip('”').str.strip('’').str.lstrip(' ').str.rstrip(' ')
non_rep['final'] = non_rep['final'].astype(str).str.replace('/[^a-zA-Z0-9 ]/g', '', regex=True).str.replace('\n',' ', regex=True).str.replace('—',' ', regex=True).str.strip('“').str.strip('”').str.strip('’').str.lstrip(' ').str.rstrip(' ')

# %%
non_rep.drop_duplicates(['final']).shape
# Out:
# (81, 8)

# %%
non_rep = non_rep.drop_duplicates(['final']).reset_index(drop=True)

# %%
non_rep.shape
# Out:
# (81, 8)

# %%
non_rep
# Out:
#                user_id                                               text  \
# 0   740588957797220352  lysoling da fuck outta everything bc i aint ca...
# 1           1971510733              1 coronavirus confirmed in washington
# 2           2419585452  hmmmmm could the coronavirus soon be the new p...
# 3             14413869  at 11 million people wuhan is larger than new ...
# 4           1601210089  wuhan is cutting off inflows and outflows of t...
# ..                 ...                                                ...
# 76         234855418.0  324  epidemic updates in real time 324 sars wh...
# 77         198324177.0  news grow mobility the scooter leader of latin...
# 78        1096420230.0  memo also gives guidance to specimen collectio...
# 79        1606212504.0  caixin removed its paywall for all wuhancorona...
# 80         123406653.0  breaking 21 students from chinese province at ...
#
#                                        text_duplicate  \
# 0   lysoling da fuck outta everything bc i aint ca...
# 1               1 Coronavirus confirmed in Washington
# 2   Hmmmmm, could the #coronavirus soon be the new...
# 3   At 11 million people, #Wuhan is larger than Ne...
# 4   Wuhan is cutting off inflows and outflows of t...
# ..                                                ...
# 76  最新！#武汉肺炎 增至324例！病毒大面积蔓延各省！澳洲总理紧急发言！全澳航空拉响警报！国内...
# 77  NEWS: Grow Mobility, the scooter leader of Lat...
# 78  Memo also gives guidance to specimen collectio...
# 79  Caixin removed its paywall for all #WuhanCoron...
# 80  #Breaking: 21 students from Chinese province a...
#
#                                        tokenized_text  \
# 0   [lysoling, da, fuck, outta, everything, bc, i,...
# 1         [1, coronavirus, confirmed, in, washington]
# 2   [hmmmmm, could, the, coronavirus, soon, be, th...
# 3   [at, 11, million, people, wuhan, is, larger, t...
# 4   [wuhan, is, cutting, off, inflows, and, outflo...
# ..                                                ...
# 76  [324, epidemic, updates, in, real, time, 324, ...
# 77  [news, grow, mobility, the, scooter, leader, o...
# 78  [memo, also, gives, guidance, to, specimen, co...
# 79  [caixin, removed, its, paywall, for, all, wuha...
# 80  [breaking, 21, students, from, chinese, provin...
#
#                                         filtered_text  \
# 0   [lysoling, da, fuck, outta, everything, bc, ai...
# 1             [1, coronavirus, confirmed, washington]
# 2   [hmmmmm, could, the, coronavirus, soon, the, n...
# 3   [at, 11, million, people, wuhan, larger, new, ...
# 4   [wuhan, cutting, inflows, outflows, transport,...
# ..                                                ...
# 76  [324, epidemic, updates, real, time, 324, sars...
# 77  [news, grow, mobility, the, scooter, leader, l...
# 78  [memo, also, gives, guidance, to, specimen, co...
# 79  [caixin, removed, paywall, wuhancoronavirus, r...
# 80  [breaking, 21, students, from, chinese, provin...
#
#                                          stemmed_text  \
# 0   [lysol, da, fuck, outta, everyth, bc, aint, ca...
# 1                [1, coronaviru, confirm, washington]
# 2   [hmmmmm, could, the, coronaviru, soon, the, ne...
# 3   [at, 11, million, peopl, wuhan, larger, new, y...
# 4   [wuhan, cut, inflow, outflow, transport, annou...
# ..                                                ...
# 76  [324, epidem, updat, real, time, 324, sar, 20196]
# 77  [news, grow, mobil, the, scooter, leader, lati...
# 78  [memo, also, give, guidanc, to, specimen, coll...
# 79  [caixin, remov, paywal, wuhancoronaviru, relat...
# 80  [break, 21, student, from, chines, provinc, at...
#
#                                       lemmatized_text  \
# 0   [lysoling, da, fuck, outta, everything, bc, ai...
# 1               [1, coronavirus, confirm, washington]
# 2   [hmmmmm, could, the, coronavirus, soon, the, n...
# 3   [at, 11, million, people, wuhan, large, new, y...
# 4   [wuhan, cut, inflow, outflow, transport, annou...
# ..                                                ...
# 76  [324, epidemic, update, real, time, 324, sars,...
# 77  [news, grow, mobility, the, scooter, leader, l...
# 78  [memo, also, give, guidance, to, specimen, col...
# 79  [caixin, remove, paywall, wuhancoronavirus, re...
# 80  [break, 21, student, from, chinese, province, ...
#
#                                                 final
# 0   lysoling da fuck outta everything bc aint catc...
# 1                    1 coronavirus confirm washington
# 2    hmmmmm could the coronavirus soon the new plague
# 3   at 11 million people wuhan large new york city...
# 4   wuhan cut inflow outflow transport announce 2a...
# ..                                                ...
# 76       324 epidemic update real time 324 sars 20196
# 77  news grow mobility the scooter leader latin am...
# 78  memo also give guidance to specimen collection...
# 79  caixin remove paywall wuhancoronavirus related...
# 80  break 21 student from chinese province at cent...
#
# [81 rows x 8 columns]

# %%
cols = [0,2, 7]
data_final = non_rep[non_rep.columns.values[cols]]
data_final.to_csv('/home/manikya_varshney/Documents/Python/Yale/All Graphs/Jan-Feb-Mar/Jan-Feb-Mar-Data/January/January22nd.csv',index=False)
