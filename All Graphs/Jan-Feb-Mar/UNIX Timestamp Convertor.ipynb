# %%
import pandas as pd
import numpy as np 
import csv
import re
import string
import datetime 

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

import warnings
warnings.filterwarnings("ignore")

# %%
path = '/home/manikya_varshney/Documents/Python/Yale/All Graphs/Jan-Feb-Mar/Jan-Feb-Mar-Data/March/March.csv'

with open(path, 'r') as f:
    reader = csv.reader(f)
    linenumber = 1
    try:
        for row in reader:
            linenumber += 1
    except Exception as e:
        print (("Error line %d: %s %s" % (linenumber, str(type(e)), e)))

# %%
data = pd.read_csv( path, index_col=None, header=0, engine='python' )

# %%
data
# Out:
#        account_created_at  account_lang  \
# 0              1502762658           NaN
# 1              1244232695           NaN
# 2              1466474458           NaN
# 3              1238708755           NaN
# 4              1290530292           NaN
# ...                   ...           ...
# 231111         1240620044           NaN
# 231112         1527632150           NaN
# 231113         1423140706           NaN
# 231114         1484528709           NaN
# 231115         1374117042           NaN
#
#                                               bbox_coords coords_coords  \
# 0       c(-75.017153, -74.927195, -74.927195, -75.0171...     c(NA, NA)
# 1       c(-87.798798, -87.7202677, -87.7202677, -87.79...     c(NA, NA)
# 2       c(-121.3461003, -121.291344, -121.291344, -121...     c(NA, NA)
# 3       c(-87.022482, -86.560616, -86.560616, -87.0224...     c(NA, NA)
# 4       c(-77.316269, -77.239245, -77.239245, -77.3162...     c(NA, NA)
# ...

# %%
data['created_at']
# Out:
# 0         1583427085
# 1         1583427093
# 2         1583427101
# 3         1583427105
# 4         1583427108
#              ...
# 231111    1585094369
# 231112    1585094375
# 231113    1585094385
# 231114    1585094386
# 231115    1585094387
# Name: created_at, Length: 231116, dtype: object

# %%
nan_value = float("NaN")
data['created_at'].replace("False", nan_value, inplace=True)

# %%
data['created_at'] = pd.to_numeric(data['created_at'])

# %%
data['created_at'] = pd.to_datetime(data['created_at'], unit='s')

# %%
data['created_at']
# Out:
# 0        2020-03-05 16:51:25
# 1        2020-03-05 16:51:33
# 2        2020-03-05 16:51:41
# 3        2020-03-05 16:51:45
# 4        2020-03-05 16:51:48
#                  ...
# 231111   2020-03-24 23:59:29
# 231112   2020-03-24 23:59:35
# 231113   2020-03-24 23:59:45
# 231114   2020-03-24 23:59:46
# 231115   2020-03-24 23:59:47
# Name: created_at, Length: 231116, dtype: datetime64[ns]

# %%
data
# Out:
#        account_created_at  account_lang  \
# 0              1502762658           NaN
# 1              1244232695           NaN
# 2              1466474458           NaN
# 3              1238708755           NaN
# 4              1290530292           NaN
# ...                   ...           ...
# 231111         1240620044           NaN
# 231112         1527632150           NaN
# 231113         1423140706           NaN
# 231114         1484528709           NaN
# 231115         1374117042           NaN
#
#                                               bbox_coords coords_coords  \
# 0       c(-75.017153, -74.927195, -74.927195, -75.0171...     c(NA, NA)
# 1       c(-87.798798, -87.7202677, -87.7202677, -87.79...     c(NA, NA)
# 2       c(-121.3461003, -121.291344, -121.291344, -121...     c(NA, NA)
# 3       c(-87.022482, -86.560616, -86.560616, -87.0224...     c(NA, NA)
# 4       c(-77.316269, -77.239245, -77.239245, -77.3162...     c(NA, NA)
# ...

# %%
data.to_csv('/home/manikya_varshney/Documents/Python/Yale/All Graphs/Jan-Feb-Mar/Jan-Feb-Mar-Data/March/(Final)March.csv',index=False)
