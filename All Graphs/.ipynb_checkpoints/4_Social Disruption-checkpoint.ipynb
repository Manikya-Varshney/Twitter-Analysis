# %% [raw]
# !pip install -U python-Levenshtein

# %% [raw]
# import sys
# !{sys.executable} -m pip install python-Levenshtein

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import string

import nltk
from nltk import pos_tag, pos_tag_sents
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) - set(['at', 'do', 'your', 'from', 'to', 'out', 'no', 'the'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
path = '/home/manikya_varshney/Documents/Python/Yale/All Graphs/final_processed_data/final_processed_april10.csv'
data = pd.read_csv(path, low_memory=False)

# %% [raw]
# social functions
# gathering
# empty streets
# interaction
# large
# no cars
# non-essential
# travel
# unnecessary
# crowd

# %%
keywords = ['social functions' , 'gathering', 'empty streets', 
            'interaction', 'large', 'no cars', 'non-essential',
            'travel', 'unnecessary', 'crowd',]

# %% [markdown]
# ##### 1. Casing (Upper or lower case)
# ##### 2. Noise Removal (Removal of punctuation, white spaces, special characters, HTML tags)
# ##### 3. Tokenization (Tweets to tokens i.e. words seprated by spaces)
# ##### 4. Stopword Removal
# ##### 5. Text Normalization (Stemming and Lemmatization)

# %%
#Convert to lower
for i in range(len(keywords)): 
    keywords[i] = keywords[i].lower()

#Remove punctuations   
for i in range(len(keywords)): 
    keywords[i] = keywords[i].translate(str.maketrans('','',string.punctuation))

#More cleaning
for i in range(len(keywords)): 
    keywords[i] = keywords[i].replace('/[^a-zA-Z0-9 ]/g', '').replace('\n',' ').strip('“').strip('“').strip('’').lstrip(' ').rstrip(' ')

#Tokenize
#keywords_tokens = [sub.split() for sub in keywords] 

#Remove stop words
def remove_stopwords(data):
    output_array=[]
    for sentence in data:
        temp_list=[]
        for word in sentence.split():
            if word not in stop_words:
                temp_list.append(word)
        output_array.append(' '.join(temp_list))
    return output_array

keywords_filtered=remove_stopwords(keywords)

#Stemming
ps = PorterStemmer()
keywords_stem = [[ps.stem(word) for word in sentence.split(" ")] for sentence in keywords_filtered]
keywords_stem = [" ".join(sentence) for sentence in keywords_stem]

#Lemmetizing

#POSTags
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

lemmatizer = WordNetLemmatizer()
keywords_lem = [[lemmatizer.lemmatize(y, get_wordnet_pos(y)) for y in sentence.split(" ")] for sentence in keywords_filtered]
keywords_final = [" ".join(sentence) for sentence in keywords_lem]

# %% [markdown]
# ## Fuzzy Matching

# %%
data['final'] = data['final'].apply(str)
choices = data['final'].tolist()

# %%
 def fuzzy_m(row):
        keyword_match, score = process.extractOne(row['final'], keywords_final, scorer = fuzz.partial_ratio)
        row['final_score'] = score
        row['final_keyword_match'] = keyword_match
        return row

# %%
interim_sd = data.apply(fuzzy_m, axis=1)

# %%
interim_sd
# Out:
#             user_id                                     text_duplicate  \
# 0      2.879999e+09  @MeetThePress @chucktodd If Trump is doing suc...
# 1      1.631563e+09  @MyCielola, @FIOB_Oficial, @MayanLeague among ...
# 2      4.175449e+08  It’s spring break and I’m supposed to be visit...
# 3      1.003550e+09  One of my hardworking pharmacy techs fell ill ...
# 4      1.238635e+18  Looking for a quarantine boyfriend. Just text ...
# ...             ...                                                ...
# 12993  3.821768e+08  Tonight’s virtual town hall with the RNS COVID...
# 12994  1.230608e+18  ICYMI: Commissioner @HodgenMainda is featured ...
# 12995  1.238883e+18  COVID Insurance Update 4/9/2020 https://t.co/j...
# 12996  1.039776e+08  Good thing there are no rush hours these days....
# 12997  7.506050e+07  Salud Para la Gente asked Leadership Award rec...
#
#                                                    final  final_score  \
# 0      trump great job the usa 30 the global covid19 ...           67
# 1      among indigenous organization denounce discrim...           60
# 2      spring break  suppose to visit family tuscaloo...           60
# 3      one hardworking pharmacy tech fell ill today c...           67
# 4      look quarantine boyfriend text good morning go...           67
# ...                                                  ...          ...
# 12993  tonight  virtual town hall the rn covid19 task...           60
# 12994  icymi commissioner feature the new issue the t...           60
# 12995                  covid insurance update 492020 via           60
# 12996  good thing no rush hour day sq issue 1546 fine...           67
# 12997  salud para la gente ask leadership award recip...           80
#
#       final_keyword_match
# 0                  no car
# 1                   crowd
# 2                   large
# 3                  no car
# 4                  no car
# ...                   ...
# 12993               crowd
# 12994               crowd
# 12995               crowd
# 12996              no car
# 12997               large
#
# [12998 rows x 5 columns]

# %%
denominator = interim_sd.shape[0]

# %%
interim_sd['final_score'] = interim_sd['final_score'].astype(int)

# %%
interim_sd = interim_sd[interim_sd['final_score'] == 100]

# %%
interim_sd
# Out:
#             user_id                                     text_duplicate  \
# 142    4.687512e+07  'The need is overwhelming': Hundreds crowd foo...
# 160    2.781855e+07  Michigan Stay At Home Order Bans 'Travel Betwe...
# 175    3.286792e+09  So many cars (and people!) here in Eloy for a ...
# 291    5.406287e+08  Kentucky officials will record the license pla...
# 447    2.575402e+08  This is how Costco is controlling the crowds. ...
# ...             ...                                                ...
# 12722  2.492040e+07  NEW: Baltimore is releasing COVID-19 cases by ...
# 12763  7.592510e+05  Ammon Bundy, the rancher who led an armed occu...
# 12799  7.592510e+05  "I am not trying to suppress religion. I'm jus...
# 12859  2.918161e+09  If you could travel anywhere, \n\nWhere would ...
# 12983  3.373715e+09  In the Spirit of Easter therefore, and after a...
#
#                                                    final  final_score  \
# 142    the need overwhelm hundred crowd food giveaway...          100
# 160    michigan stay at home order ban travel two res...          100
# 175    many car people eloy caravan to demand immigra...          100
# 291    kentucky official record the license plate ind...          100
# 447    costco control the crowd enter wait single fil...          100
# ...                                                  ...          ...
# 12722  new baltimore release covid19 case zip code da...          100
# 12763  ammon bundy the rancher lead arm occupation fe...          100
# 12799  try to suppress religion im try to save kansan...          100
# 12859                     could travel anywhere would go          100
# 12983  the spirit easter therefore careful review the...          100
#
#       final_keyword_match
# 142                 crowd
# 160                travel
# 175                 crowd
# 291             gathering
# 447                 crowd
# ...                   ...
# 12722               large
# 12763           gathering
# 12799           gathering
# 12859              travel
# 12983           gathering
#
# [172 rows x 5 columns]

# %%
numerator = interim_sd.shape[0]

# %%
proportion = (numerator/denominator)
print(proportion)
# Out:
# 0.013232805046930297
