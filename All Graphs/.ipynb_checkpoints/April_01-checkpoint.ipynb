# %%
import pandas as pd
import numpy as np 
import csv
import re
import string

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

import warnings
warnings.filterwarnings("ignore")

# %%
path = '/home/manikya_varshney/Documents/Python/Yale/Graph Data/april01.csv'
data = pd.read_csv(path, low_memory=False)

# %%
data.shape
# Out:
# (16190, 14)

# %%
data['lang'].value_counts()
# Out:
# en    16190
# Name: lang, dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ##### is_quote --> False

# %%
interim = data[np.where((data['is_quote']==False),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (14699, 14)

# %%
non_rep = interim[['user_id','status_id','text']]

# %%
non_rep.shape
# Out:
# (14699, 3)

# %%
non_rep.drop_duplicates(['status_id']).shape
# Out:
# (14699, 3)

# %%
non_rep = non_rep.drop_duplicates(['status_id']).reset_index(drop=True)

# %% [markdown]
# ##### is_quote --> True

# %%
interim = data[np.where((data['is_quote']== True),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (1491, 14)

# %%
interim = interim[['user_id','status_id','text']]

# %%
interim.columns = non_rep.columns

# %%
interim.drop_duplicates(['user_id','status_id']).shape
# Out:
# (1491, 3)

# %%
interim = interim.drop_duplicates(['user_id','status_id']).reset_index(drop=True)

# %%
interim.shape
# Out:
# (1491, 3)

# %%
non_rep = non_rep.append(interim,ignore_index=True)

# %%
non_rep.shape
# Out:
# (16190, 3)

# %%
non_rep.drop_duplicates(['user_id','status_id']).shape
# Out:
# (16190, 3)

# %%
non_rep = non_rep.drop_duplicates(['user_id','status_id']).reset_index(drop=True)

# %%
non_rep.shape
# Out:
# (16190, 3)

# %%
interim = data[np.where((data['is_quote']== True),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (1491, 14)

# %%
interim[['quoted_text']]
# Out:
#                                             quoted_text
# 0     Saw this research paper here on twitter and I ...
# 1     The Guardian view on Jair Bolsonaro: a danger ...
# 2     An engineer deliberately ran a train off the t...
# 3     Soooo saaaaaaaad to finally announce this, but...
# 4     I’m gonna give away $5,000 to 3 random people ...
# ...                                                 ...
# 1486  Part of a 1938 public health map: https://t.co...
# 1487  A New York radio reporter, a party on LBI, and...
# 1488  This White House briefing room slide lists as ...
# 1489  While the resourcefulness and hustle shown by ...
# 1490  Six days ago, there were 13,355 new coronaviru...
#
# [1491 rows x 1 columns]

# %%
interim = interim[['user_id','status_id','quoted_text']]

# %%
interim.columns = non_rep.columns

# %%
interim
# Out:
#                  user_id            status_id  \
# 0              255191504  1245500823393587202
# 1              930737041  1245500682586615809
# 2               16083327  1245500649242066944
# 3             4914305528  1245500604358832131
# 4              271914838  1245500367972040704
# ...                  ...                  ...
# 1486  751644712570847236  1245149093137178624
# 1487           286628737  1245149027609403397
# 1488           361010205  1245148960265666561
# 1489           481389842  1245148653708120064
# 1490            11347222  1245148514058895365
#
#                                                    text
# 0     Saw this research paper here on twitter and I ...
# 1     The Guardian view on Jair Bolsonaro: a danger ...
# 2     An engineer deliberately ran a train off the t...
# 3     Soooo saaaaaaaad to finally announce this, but...
# 4     I’m gonna give away $5,000 to 3 random people ...
# ...                                                 ...
# 1486  Part of a 1938 public health map: https://t.co...
# 1487  A New York radio reporter, a party on LBI, and...
# 1488  This White House briefing room slide lists as ...
# 1489  While the resourcefulness and hustle shown by ...
# 1490  Six days ago, there were 13,355 new coronaviru...
#
# [1491 rows x 3 columns]

# %%
interim.drop_duplicates(['user_id','status_id']).shape
# Out:
# (1491, 3)

# %%
interim = interim.drop_duplicates(['user_id','status_id']).reset_index(drop=True)

# %%
non_rep = non_rep.append(interim,ignore_index=True)

# %%
non_rep.shape
# Out:
# (17681, 3)

# %%
non_rep.drop_duplicates(['user_id','status_id']).shape
# Out:
# (16190, 3)

# %%
non_rep = non_rep.drop_duplicates(['user_id','status_id']).reset_index(drop=True)

# %%
non_rep
# Out:
#                   user_id            status_id  \
# 0                28433993  1245501156002074624
# 1               101043870  1245501124997611520
# 2                16475267  1245501112884408321
# 3                16475267  1245501115010973697
# 4               345397708  1245501037403873283
# ...                   ...                  ...
# 16185  751644712570847236  1245149093137178624
# 16186           286628737  1245149027609403397
# 16187           361010205  1245148960265666561
# 16188           481389842  1245148653708120064
# 16189            11347222  1245148514058895365
#
#                                                     text
# 0      As Chicago households fill out 2020 census dur...
# 1      Most of the press corps is very busy covering ...
# 2      @realDonaldTrump Mar 10–he was very specific: ...
# 3      @realDonaldTrump , You were caustic &amp; sarc...
# 4      Florida nears 8,000 coronavirus cases, as stat...
# ...                                                  ...
# 16185  If in 1938 Turkey’s government could produce a...
# 16186  Sandy Medford was a friend of my family for de...
# 16187  One month ago Trump claimed the number of Amer...
# 16188  Yes. This. Especially if a substantial proport...
# 16189  I'm sticking to my original lowball prediction...
#
# [16190 rows x 3 columns]

# %% [markdown]
# # Analysis

# %%
import pandas as pd
import numpy as np 
import csv
import re
import string
import emoji

import nltk
from nltk import pos_tag, pos_tag_sents
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

import warnings
warnings.filterwarnings("ignore")

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
stop_words = set(stopwords.words('english')) - set(['at', 'do', 'your', 'from', 'to', 'out', 'no', 'the'])
#demoji.download_codes()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
non_rep['text_duplicate'] = non_rep['text']

# %%
non_rep
# Out:
#                   user_id            status_id  \
# 0                28433993  1245501156002074624
# 1               101043870  1245501124997611520
# 2                16475267  1245501112884408321
# 3                16475267  1245501115010973697
# 4               345397708  1245501037403873283
# ...                   ...                  ...
# 16185  751644712570847236  1245149093137178624
# 16186           286628737  1245149027609403397
# 16187           361010205  1245148960265666561
# 16188           481389842  1245148653708120064
# 16189            11347222  1245148514058895365
#
#                                                     text  \
# 0      As Chicago households fill out 2020 census dur...
# 1      Most of the press corps is very busy covering ...
# 2      @realDonaldTrump Mar 10–he was very specific: ...
# 3      @realDonaldTrump , You were caustic &amp; sarc...
# 4      Florida nears 8,000 coronavirus cases, as stat...
# ...                                                  ...
# 16185  If in 1938 Turkey’s government could produce a...
# 16186  Sandy Medford was a friend of my family for de...
# 16187  One month ago Trump claimed the number of Amer...
# 16188  Yes. This. Especially if a substantial proport...
# 16189  I'm sticking to my original lowball prediction...
#
#                                           text_duplicate
# 0      As Chicago households fill out 2020 census dur...
# 1      Most of the press corps is very busy covering ...
# 2      @realDonaldTrump Mar 10–he was very specific: ...
# 3      @realDonaldTrump , You were caustic &amp; sarc...
# 4      Florida nears 8,000 coronavirus cases, as stat...
# ...                                                  ...
# 16185  If in 1938 Turkey’s government could produce a...
# 16186  Sandy Medford was a friend of my family for de...
# 16187  One month ago Trump claimed the number of Amer...
# 16188  Yes. This. Especially if a substantial proport...
# 16189  I'm sticking to my original lowball prediction...
#
# [16190 rows x 4 columns]

# %%
#Convert to lower case
non_rep['text'] = non_rep['text'].str.lower()

# %%
#Removing emojis
def demoji(text):
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U00010000-\U0010ffff"
                               "]+", flags=re.UNICODE)
    return(emoji_pattern.sub(r'', text))

non_rep[u'text'] = non_rep[u'text'].astype(str)
non_rep[u'text'] = non_rep[u'text'].apply(lambda x:demoji(x))

# %%
#Remove URLs
non_rep['text'] = non_rep['text'].str.replace(r"http\S+| www\S+| https\S+| \S+\.com\S+| \S+\.com", "", regex=True)

# %%
#Remove user @
non_rep['text'] = non_rep['text'].str.replace(r'\@[\w]+', "", regex=True)

# %%
#Remove punctuations
non_rep['text'] = non_rep['text'].str.translate(str.maketrans("", "", string.punctuation))

# %%
#More Cleaning
non_rep['text']=non_rep['text'].astype(str).str.replace('/[^a-zA-Z0-9 ]/g', '', regex=True).str.replace('\n',' ', regex=True).str.replace('—',' ', regex=True).str.strip('“').str.strip('”').str.strip('’').str.lstrip(' ').str.rstrip(' ')

# %%
#Tokenizing
non_rep.text = non_rep.text.astype(str)
non_rep['tokenized_text'] = non_rep.apply(lambda row: nltk.word_tokenize(row.text), axis=1)

# remove stopwords
non_rep['filtered_text'] = non_rep['tokenized_text'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
#Stemming
ps = PorterStemmer()
non_rep['stemmed_text'] = non_rep['filtered_text'].apply(lambda x: [ps.stem(y) for y in x])

# %%
#POSTags
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
#Lemmatizing
lemmatizer = WordNetLemmatizer()
non_rep['lemmatized_text'] = non_rep['filtered_text'].apply(lambda x: [lemmatizer.lemmatize(y, get_wordnet_pos(y)) for y in x])

# %%
#Joining the lemmetized tokens to form string
non_rep['final'] = non_rep['lemmatized_text'].apply(lambda x: " ".join([word for word in x]))

# %%
#Remove punctuations
non_rep['final'] = non_rep['final'].str.translate(str.maketrans("", "", string.punctuation))
non_rep['final'] = non_rep['final'].str.replace("’", '').str.replace("“", '').str.replace("”", '')
non_rep['text'] = non_rep['text'].astype(str).str.replace('/[^a-zA-Z0-9 ]/g', '', regex=True).str.replace('\n',' ', regex=True).str.replace('—',' ', regex=True).str.strip('“').str.strip('”').str.strip('’').str.lstrip(' ').str.rstrip(' ')

# %%
non_rep
# Out:
#                   user_id            status_id  \
# 0                28433993  1245501156002074624
# 1               101043870  1245501124997611520
# 2                16475267  1245501112884408321
# 3                16475267  1245501115010973697
# 4               345397708  1245501037403873283
# ...                   ...                  ...
# 16185  751644712570847236  1245149093137178624
# 16186           286628737  1245149027609403397
# 16187           361010205  1245148960265666561
# 16188           481389842  1245148653708120064
# 16189            11347222  1245148514058895365
#
#                                                     text  \
# 0      as chicago households fill out 2020 census dur...
# 1      most of the press corps is very busy covering ...
# 2      mar 10–he was very specific “google has 1700 e...
# 3      you were caustic amp sarcastic about the rollo...
# 4      florida nears 8000 coronavirus cases as state ...
# ...                                                  ...
# 16185  if in 1938 turkey’s government could produce a...
# 16186  sandy medford was a friend of my family for de...
# 16187  one month ago trump claimed the number of amer...
# 16188  yes this especially if a substantial proportio...
# 16189  im sticking to my original lowball prediction ...
#
#                                           text_duplicate  \
# 0      As Chicago households fill out 2020 census dur...
# 1      Most of the press corps is very busy covering ...
# 2      @realDonaldTrump Mar 10–he was very specific: ...
# 3      @realDonaldTrump , You were caustic &amp; sarc...
# 4      Florida nears 8,000 coronavirus cases, as stat...
# ...                                                  ...
# 16185  If in 1938 Turkey’s government could produce a...
# 16186  Sandy Medford was a friend of my family for de...
# 16187  One month ago Trump claimed the number of Amer...
# 16188  Yes. This. Especially if a substantial proport...
# 16189  I'm sticking to my original lowball prediction...
#
#                                           tokenized_text  \
# 0      [as, chicago, households, fill, out, 2020, cen...
# 1      [most, of, the, press, corps, is, very, busy, ...
# 2      [mar, 10–he, was, very, specific, “, google, h...
# 3      [you, were, caustic, amp, sarcastic, about, th...
# 4      [florida, nears, 8000, coronavirus, cases, as,...
# ...                                                  ...
# 16185  [if, in, 1938, turkey, ’, s, government, could...
# 16186  [sandy, medford, was, a, friend, of, my, famil...
# 16187  [one, month, ago, trump, claimed, the, number,...
# 16188  [yes, this, especially, if, a, substantial, pr...
# 16189  [im, sticking, to, my, original, lowball, pred...
#
#                                            filtered_text  \
# 0      [chicago, households, fill, out, 2020, census,...
# 1      [the, press, corps, busy, covering, the, reall...
# 2      [mar, 10–he, specific, “, google, 1700, engine...
# 3      [caustic, amp, sarcastic, the, rollout, ’, com...
# 4      [florida, nears, 8000, coronavirus, cases, sta...
# ...                                                  ...
# 16185  [1938, turkey, ’, government, could, produce, ...
# 16186  [sandy, medford, friend, family, decades, susp...
# 16187  [one, month, ago, trump, claimed, the, number,...
# 16188  [yes, especially, substantial, proportion, wor...
# 16189  [im, sticking, to, original, lowball, predicti...
#
#                                             stemmed_text  \
# 0      [chicago, household, fill, out, 2020, censu, c...
# 1      [the, press, corp, busi, cover, the, realli, i...
# 2      [mar, 10–he, specif, “, googl, 1700, engin, wo...
# 3      [caustic, amp, sarcast, the, rollout, ’, come,...
# 4      [florida, near, 8000, coronaviru, case, state,...
# ...                                                  ...
# 16185  [1938, turkey, ’, govern, could, produc, healt...
# 16186  [sandi, medford, friend, famili, decad, suspec...
# 16187  [one, month, ago, trump, claim, the, number, a...
# 16188  [ye, especi, substanti, proport, workforc, aff...
# 16189  [im, stick, to, origin, lowbal, predict, at, l...
#
#                                          lemmatized_text  \
# 0      [chicago, household, fill, out, 2020, census, ...
# 1      [the, press, corp, busy, cover, the, really, i...
# 2      [mar, 10–he, specific, “, google, 1700, engine...
# 3      [caustic, amp, sarcastic, the, rollout, ’, com...
# 4      [florida, nears, 8000, coronavirus, case, stat...
# ...                                                  ...
# 16185  [1938, turkey, ’, government, could, produce, ...
# 16186  [sandy, medford, friend, family, decade, suspe...
# 16187  [one, month, ago, trump, claimed, the, number,...
# 16188  [yes, especially, substantial, proportion, wor...
# 16189  [im, stick, to, original, lowball, prediction,...
#
#                                                    final
# 0      chicago household fill out 2020 census coronav...
# 1      the press corp busy cover the really important...
# 2      mar 10–he specific  google 1700 engineer work ...
# 3      caustic amp sarcastic the rollout  come even f...
# 4      florida nears 8000 coronavirus case state repo...
# ...                                                  ...
# 16185  1938 turkey  government could produce health m...
# 16186  sandy medford friend family decade suspect hea...
# 16187  one month ago trump claimed the number america...
# 16188  yes especially substantial proportion workforc...
# 16189  im stick to original lowball prediction at lea...
#
# [16190 rows x 9 columns]

# %%
cols = [0,3, 8]
data_final = non_rep[non_rep.columns.values[cols]]
data_final.to_csv('final_processed_april01.csv',index=False)

# %%
data_final
# Out:
#                   user_id                                     text_duplicate  \
# 0                28433993  As Chicago households fill out 2020 census dur...
# 1               101043870  Most of the press corps is very busy covering ...
# 2                16475267  @realDonaldTrump Mar 10–he was very specific: ...
# 3                16475267  @realDonaldTrump , You were caustic &amp; sarc...
# 4               345397708  Florida nears 8,000 coronavirus cases, as stat...
# ...                   ...                                                ...
# 16185  751644712570847236  If in 1938 Turkey’s government could produce a...
# 16186           286628737  Sandy Medford was a friend of my family for de...
# 16187           361010205  One month ago Trump claimed the number of Amer...
# 16188           481389842  Yes. This. Especially if a substantial proport...
# 16189            11347222  I'm sticking to my original lowball prediction...
#
#                                                    final
# 0      chicago household fill out 2020 census coronav...
# 1      the press corp busy cover the really important...
# 2      mar 10–he specific  google 1700 engineer work ...
# 3      caustic amp sarcastic the rollout  come even f...
# 4      florida nears 8000 coronavirus case state repo...
# ...                                                  ...
# 16185  1938 turkey  government could produce health m...
# 16186  sandy medford friend family decade suspect hea...
# 16187  one month ago trump claimed the number america...
# 16188  yes especially substantial proportion workforc...
# 16189  im stick to original lowball prediction at lea...
#
# [16190 rows x 3 columns]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
temp=' '.join(data_final['final'].tolist())
wordcloud = WordCloud(width = 800, height = 500, background_color ='white', min_font_size = 10).generate(temp)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.show()
