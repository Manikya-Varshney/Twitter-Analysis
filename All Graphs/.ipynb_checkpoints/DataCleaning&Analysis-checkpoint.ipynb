# %%
import pandas as pd
import numpy as np 
import csv
import re
import string

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

import warnings
warnings.filterwarnings("ignore")

# %%
path = '/home/manikya_varshney/Documents/Python/Yale/All Graphs/Test Data/april01.csv'
data = pd.read_csv(path, low_memory=False)

# %%
data.shape
# Out:
# (16190, 14)

# %%
data['lang'].value_counts()
# Out:
# en    16190
# Name: lang, dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ##### is_quote --> False

# %%
interim = data[np.where((data['is_quote']==False),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (14699, 14)

# %%
non_rep = interim[['user_id','text']]

# %% [raw]
# non_rep['status_id'].astype(int).nunique()

# %% [raw]
# non_rep['status_id'].nunique()

# %% [raw]
# non_rep.shape

# %% [raw]
# non_rep['text'].value_counts()

# %% [raw]
# non_rep[non_rep['text']=='@VibeUp_Music #StayHomeVibeUp https://t.co/xwoNOyyMUj hi I lost my job due to covid-19 and i am not eligible for the stimulus check :( so i’m hurting a little now please help ❤️ #vibeupmusic']

# %% [markdown]
# ##### is_quote --> True

# %%
interim = data[np.where((data['is_quote']== True),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (1491, 14)

# %%
interim = interim[['user_id','text']]

# %%
interim.columns = non_rep.columns

# %%
interim.shape
# Out:
# (1491, 2)

# %%
non_rep = non_rep.append(interim,ignore_index=True)

# %%
non_rep.shape
# Out:
# (16190, 2)

# %%
interim = data[np.where((data['is_quote']== True),True,False)].reset_index(drop=True)

# %%
interim.shape
# Out:
# (1491, 14)

# %%
interim[['quoted_text']]
# Out:
#                                             quoted_text
# 0     Saw this research paper here on twitter and I ...
# 1     The Guardian view on Jair Bolsonaro: a danger ...
# 2     An engineer deliberately ran a train off the t...
# 3     Soooo saaaaaaaad to finally announce this, but...
# 4     I’m gonna give away $5,000 to 3 random people ...
# ...                                                 ...
# 1486  Part of a 1938 public health map: https://t.co...
# 1487  A New York radio reporter, a party on LBI, and...
# 1488  This White House briefing room slide lists as ...
# 1489  While the resourcefulness and hustle shown by ...
# 1490  Six days ago, there were 13,355 new coronaviru...
#
# [1491 rows x 1 columns]

# %%
interim = interim[['quoted_user_id','quoted_text']]

# %% [raw]
# interim['status_id'] = pd.Series([np.nan]*interim.shape[0])

# %%
interim
# Out:
#       quoted_user_id                                        quoted_text
# 0       3.379014e+09  Saw this research paper here on twitter and I ...
# 1       5.128255e+07  The Guardian view on Jair Bolsonaro: a danger ...
# 2       1.899340e+07  An engineer deliberately ran a train off the t...
# 3       1.623403e+07  Soooo saaaaaaaad to finally announce this, but...
# 4       1.823623e+07  I’m gonna give away $5,000 to 3 random people ...
# ...              ...                                                ...
# 1486    9.186279e+08  Part of a 1938 public health map: https://t.co...
# 1487    1.965532e+07  A New York radio reporter, a party on LBI, and...
# 1488    2.323220e+07  This White House briefing room slide lists as ...
# 1489    1.240031e+18  While the resourcefulness and hustle shown by ...
# 1490    3.223426e+09  Six days ago, there were 13,355 new coronaviru...
#
# [1491 rows x 2 columns]

# %%
interim = interim.rename(columns={'quoted_user_id':'user_id', 'quoted_text':'text'})

# %%
non_rep = non_rep.append(interim,ignore_index=True)

# %%
non_rep.shape
# Out:
# (17681, 2)

# %%
non_rep
# Out:
#             user_id                                               text
# 0      2.843399e+07  As Chicago households fill out 2020 census dur...
# 1      1.010439e+08  Most of the press corps is very busy covering ...
# 2      1.647527e+07  @realDonaldTrump Mar 10–he was very specific: ...
# 3      1.647527e+07  @realDonaldTrump , You were caustic &amp; sarc...
# 4      3.453977e+08  Florida nears 8,000 coronavirus cases, as stat...
# ...             ...                                                ...
# 17676  9.186279e+08  Part of a 1938 public health map: https://t.co...
# 17677  1.965532e+07  A New York radio reporter, a party on LBI, and...
# 17678  2.323220e+07  This White House briefing room slide lists as ...
# 17679  1.240031e+18  While the resourcefulness and hustle shown by ...
# 17680  3.223426e+09  Six days ago, there were 13,355 new coronaviru...
#
# [17681 rows x 2 columns]

# %% [markdown]
# # Analysis

# %%
import pandas as pd
import numpy as np 
import csv
import re
import string
import emoji

import nltk
from nltk import pos_tag, pos_tag_sents
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

import warnings
warnings.filterwarnings("ignore")

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
stop_words = set(stopwords.words('english')) - set(['at', 'do', 'your', 'from', 'to', 'out', 'no', 'the'])
#demoji.download_codes()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
non_rep['text_duplicate'] = non_rep['text']

# %%
non_rep
# Out:
#             user_id                                               text  \
# 0      2.843399e+07  As Chicago households fill out 2020 census dur...
# 1      1.010439e+08  Most of the press corps is very busy covering ...
# 2      1.647527e+07  @realDonaldTrump Mar 10–he was very specific: ...
# 3      1.647527e+07  @realDonaldTrump , You were caustic &amp; sarc...
# 4      3.453977e+08  Florida nears 8,000 coronavirus cases, as stat...
# ...             ...                                                ...
# 17676  9.186279e+08  Part of a 1938 public health map: https://t.co...
# 17677  1.965532e+07  A New York radio reporter, a party on LBI, and...
# 17678  2.323220e+07  This White House briefing room slide lists as ...
# 17679  1.240031e+18  While the resourcefulness and hustle shown by ...
# 17680  3.223426e+09  Six days ago, there were 13,355 new coronaviru...
#
#                                           text_duplicate
# 0      As Chicago households fill out 2020 census dur...
# 1      Most of the press corps is very busy covering ...
# 2      @realDonaldTrump Mar 10–he was very specific: ...
# 3      @realDonaldTrump , You were caustic &amp; sarc...
# 4      Florida nears 8,000 coronavirus cases, as stat...
# ...                                                  ...
# 17676  Part of a 1938 public health map: https://t.co...
# 17677  A New York radio reporter, a party on LBI, and...
# 17678  This White House briefing room slide lists as ...
# 17679  While the resourcefulness and hustle shown by ...
# 17680  Six days ago, there were 13,355 new coronaviru...
#
# [17681 rows x 3 columns]

# %%
#Convert to lower case
non_rep['text'] = non_rep['text'].str.lower()

# %%
#Removing emojis
def demoji(text):
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U00010000-\U0010ffff"
                               "]+", flags=re.UNICODE)
    return(emoji_pattern.sub(r'', text))

non_rep[u'text'] = non_rep[u'text'].astype(str)
non_rep[u'text'] = non_rep[u'text'].apply(lambda x:demoji(x))

# %%
#Remove URLs
non_rep['text'] = non_rep['text'].str.replace(r"http\S+| www\S+| https\S+| \S+\.com\S+| \S+\.com", "", regex=True)

# %%
#Remove user @
non_rep['text'] = non_rep['text'].str.replace(r'\@[\w]+', "", regex=True)

# %%
#Remove punctuations
non_rep['text'] = non_rep['text'].str.translate(str.maketrans("", "", string.punctuation))

# %%
#More Cleaning
non_rep['text']=non_rep['text'].astype(str).str.replace('/[^a-zA-Z0-9 ]/g', '', regex=True).str.replace('\n',' ', regex=True).str.replace('—',' ', regex=True).str.strip('“').str.strip('”').str.strip('’').str.lstrip(' ').str.rstrip(' ')

# %%
#Tokenizing
non_rep.text = non_rep.text.astype(str)
non_rep['tokenized_text'] = non_rep.apply(lambda row: nltk.word_tokenize(row.text), axis=1)

# remove stopwords
non_rep['filtered_text'] = non_rep['tokenized_text'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
#Stemming
ps = PorterStemmer()
non_rep['stemmed_text'] = non_rep['filtered_text'].apply(lambda x: [ps.stem(y) for y in x])

# %%
#POSTags
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
#Lemmatizing
lemmatizer = WordNetLemmatizer()
non_rep['lemmatized_text'] = non_rep['filtered_text'].apply(lambda x: [lemmatizer.lemmatize(y, get_wordnet_pos(y)) for y in x])

# %%
#Joining the lemmetized tokens to form string
non_rep['final'] = non_rep['lemmatized_text'].apply(lambda x: " ".join([word for word in x]))

# %%
#Remove punctuations
non_rep['final'] = non_rep['final'].str.translate(str.maketrans("", "", string.punctuation))
non_rep['final'] = non_rep['final'].str.replace("’", '').str.replace("“", '').str.replace("”", '')
#non_rep['text'] = non_rep['text'].astype(str).str.replace('/[^a-zA-Z0-9 ]/g', '', regex=True).str.replace('\n',' ', regex=True).str.replace('—',' ', regex=True).str.strip('“').str.strip('”').str.strip('’').str.lstrip(' ').str.rstrip(' ')
non_rep['final'] = non_rep['final'].astype(str).str.replace('/[^a-zA-Z0-9 ]/g', '', regex=True).str.replace('\n',' ', regex=True).str.replace('—',' ', regex=True).str.strip('“').str.strip('”').str.strip('’').str.lstrip(' ').str.rstrip(' ')

# %% [raw]
# non_rep['text'].nunique()

# %% [raw]
# non_rep['final'].nunique()

# %% [raw]
# non_rep['final'].value_counts().to_frame()#.index[1]

# %% [raw]
# non_rep[non_rep['final'] == 'the cdc issue first warn jan 8 trump held campaign rally jan 9 jan 14 jan 28 jan 30 feb 10 feb 19 feb 20 feb 21 amp feb 28 golfed jan 18 jan 19 feb 1 feb 15 mar 7 amp mar 8 the first time admit the coronavirus might problem mar 13'
# ]['text_duplicate'].loc[3571]

# %%
non_rep.drop_duplicates(['final']).shape
# Out:
# (16925, 8)

# %%
non_rep = non_rep.drop_duplicates(['final']).reset_index(drop=True)

# %%
non_rep.shape
# Out:
# (16925, 8)

# %%
non_rep
# Out:
#             user_id                                               text  \
# 0      2.843399e+07  as chicago households fill out 2020 census dur...
# 1      1.010439e+08  most of the press corps is very busy covering ...
# 2      1.647527e+07  mar 10–he was very specific “google has 1700 e...
# 3      1.647527e+07  you were caustic amp sarcastic about the rollo...
# 4      3.453977e+08  florida nears 8000 coronavirus cases as state ...
# ...             ...                                                ...
# 16920  9.832288e+17  sierraleone has registered its index case of c...
# 16921  1.856380e+07  ktar news reporter  gives a coronavirus update...
# 16922  9.186279e+08                   part of a 1938 public health map
# 16923  1.240031e+18  while the resourcefulness and hustle shown by ...
# 16924  3.223426e+09  six days ago there were 13355 new coronavirus ...
#
#                                           text_duplicate  \
# 0      As Chicago households fill out 2020 census dur...
# 1      Most of the press corps is very busy covering ...
# 2      @realDonaldTrump Mar 10–he was very specific: ...
# 3      @realDonaldTrump , You were caustic &amp; sarc...
# 4      Florida nears 8,000 coronavirus cases, as stat...
# ...                                                  ...
# 16920  #SierraLeone has registered its index case of ...
# 16921  KTAR News reporter @TaylorKinnerup gives a cor...
# 16922  Part of a 1938 public health map: https://t.co...
# 16923  While the resourcefulness and hustle shown by ...
# 16924  Six days ago, there were 13,355 new coronaviru...
#
#                                           tokenized_text  \
# 0      [as, chicago, households, fill, out, 2020, cen...
# 1      [most, of, the, press, corps, is, very, busy, ...
# 2      [mar, 10–he, was, very, specific, “, google, h...
# 3      [you, were, caustic, amp, sarcastic, about, th...
# 4      [florida, nears, 8000, coronavirus, cases, as,...
# ...                                                  ...
# 16920  [sierraleone, has, registered, its, index, cas...
# 16921  [ktar, news, reporter, gives, a, coronavirus, ...
# 16922           [part, of, a, 1938, public, health, map]
# 16923  [while, the, resourcefulness, and, hustle, sho...
# 16924  [six, days, ago, there, were, 13355, new, coro...
#
#                                            filtered_text  \
# 0      [chicago, households, fill, out, 2020, census,...
# 1      [the, press, corps, busy, covering, the, reall...
# 2      [mar, 10–he, specific, “, google, 1700, engine...
# 3      [caustic, amp, sarcastic, the, rollout, ’, com...
# 4      [florida, nears, 8000, coronavirus, cases, sta...
# ...                                                  ...
# 16920  [sierraleone, registered, index, case, covid19...
# 16921  [ktar, news, reporter, gives, coronavirus, upd...
# 16922                  [part, 1938, public, health, map]
# 16923  [the, resourcefulness, hustle, shown, many, to...
# 16924  [six, days, ago, 13355, new, coronavirus, case...
#
#                                             stemmed_text  \
# 0      [chicago, household, fill, out, 2020, censu, c...
# 1      [the, press, corp, busi, cover, the, realli, i...
# 2      [mar, 10–he, specif, “, googl, 1700, engin, wo...
# 3      [caustic, amp, sarcast, the, rollout, ’, come,...
# 4      [florida, near, 8000, coronaviru, case, state,...
# ...                                                  ...
# 16920  [sierraleon, regist, index, case, covid19, fro...
# 16921  [ktar, news, report, give, coronaviru, updat, ...
# 16922                  [part, 1938, public, health, map]
# 16923  [the, resourc, hustl, shown, mani, to, produc,...
# 16924  [six, day, ago, 13355, new, coronaviru, case, ...
#
#                                          lemmatized_text  \
# 0      [chicago, household, fill, out, 2020, census, ...
# 1      [the, press, corp, busy, cover, the, really, i...
# 2      [mar, 10–he, specific, “, google, 1700, engine...
# 3      [caustic, amp, sarcastic, the, rollout, ’, com...
# 4      [florida, nears, 8000, coronavirus, case, stat...
# ...                                                  ...
# 16920  [sierraleone, register, index, case, covid19, ...
# 16921  [ktar, news, reporter, give, coronavirus, upda...
# 16922                  [part, 1938, public, health, map]
# 16923  [the, resourcefulness, hustle, show, many, to,...
# 16924  [six, day, ago, 13355, new, coronavirus, case,...
#
#                                                    final
# 0      chicago household fill out 2020 census coronav...
# 1      the press corp busy cover the really important...
# 2      mar 10–he specific  google 1700 engineer work ...
# 3      caustic amp sarcastic the rollout  come even f...
# 4      florida nears 8000 coronavirus case state repo...
# ...                                                  ...
# 16920  sierraleone register index case covid19 from d...
# 16921  ktar news reporter give coronavirus update ari...
# 16922                        part 1938 public health map
# 16923  the resourcefulness hustle show many to produc...
# 16924  six day ago 13355 new coronavirus case daily t...
#
# [16925 rows x 8 columns]

# %%
cols = [0,2, 7]
data_final = non_rep[non_rep.columns.values[cols]]
data_final.to_csv('/home/manikya_varshney/Documents/Python/Yale/All Graphs/Test Data/final_processed_april01.csv',index=False)

# %%
data_final
# Out:
#             user_id                                     text_duplicate  \
# 0      2.843399e+07  As Chicago households fill out 2020 census dur...
# 1      1.010439e+08  Most of the press corps is very busy covering ...
# 2      1.647527e+07  @realDonaldTrump Mar 10–he was very specific: ...
# 3      1.647527e+07  @realDonaldTrump , You were caustic &amp; sarc...
# 4      3.453977e+08  Florida nears 8,000 coronavirus cases, as stat...
# ...             ...                                                ...
# 16920  9.832288e+17  #SierraLeone has registered its index case of ...
# 16921  1.856380e+07  KTAR News reporter @TaylorKinnerup gives a cor...
# 16922  9.186279e+08  Part of a 1938 public health map: https://t.co...
# 16923  1.240031e+18  While the resourcefulness and hustle shown by ...
# 16924  3.223426e+09  Six days ago, there were 13,355 new coronaviru...
#
#                                                    final
# 0      chicago household fill out 2020 census coronav...
# 1      the press corp busy cover the really important...
# 2      mar 10–he specific  google 1700 engineer work ...
# 3      caustic amp sarcastic the rollout  come even f...
# 4      florida nears 8000 coronavirus case state repo...
# ...                                                  ...
# 16920  sierraleone register index case covid19 from d...
# 16921  ktar news reporter give coronavirus update ari...
# 16922                        part 1938 public health map
# 16923  the resourcefulness hustle show many to produc...
# 16924  six day ago 13355 new coronavirus case daily t...
#
# [16925 rows x 3 columns]

# %% [raw]
# data_final[data_final['final'].isna()]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
temp=' '.join(data_final['final'].tolist())
wordcloud = WordCloud(width = 800, height = 500, background_color ='white', min_font_size = 10).generate(temp)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.show()
