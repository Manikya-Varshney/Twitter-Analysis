# %% [raw]
# !pip install -U python-Levenshtein

# %% [raw]
# import sys
# !{sys.executable} -m pip install python-Levenshtein

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import string

import nltk
from nltk import pos_tag, pos_tag_sents
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) - set(['at', 'do', 'your', 'from', 'to', 'out', 'no', 'the'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/manikya_varshney/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
path = '/home/manikya_varshney/Documents/Python/Yale/All Graphs/final_processed_data/final_processed_april10.csv'
data = pd.read_csv(path, low_memory=False)

# %% [raw]
# Flatten the curve
# Slow the spread
# slow transmission
# protect
# save
# #stayhomesavelives

# %%
keywords = ['Flatten the curve' , 'Slow the spread', 'slow transmission', 
            'protect', 'save', '#stayhomesavelives']

# %% [markdown]
# ##### 1. Casing (Upper or lower case)
# ##### 2. Noise Removal (Removal of punctuation, white spaces, special characters, HTML tags)
# ##### 3. Tokenization (Tweets to tokens i.e. words seprated by spaces)
# ##### 4. Stopword Removal
# ##### 5. Text Normalization (Stemming and Lemmatization)

# %%
#Convert to lower
for i in range(len(keywords)): 
    keywords[i] = keywords[i].lower()

#Remove punctuations   
for i in range(len(keywords)): 
    keywords[i] = keywords[i].translate(str.maketrans('','',string.punctuation))

#More cleaning
for i in range(len(keywords)): 
    keywords[i] = keywords[i].replace('/[^a-zA-Z0-9 ]/g', '').replace('\n',' ').strip('“').strip('“').strip('’').lstrip(' ').rstrip(' ')

#Tokenize
#keywords_tokens = [sub.split() for sub in keywords] 

#Remove stop words
def remove_stopwords(data):
    output_array=[]
    for sentence in data:
        temp_list=[]
        for word in sentence.split():
            if word not in stop_words:
                temp_list.append(word)
        output_array.append(' '.join(temp_list))
    return output_array

keywords_filtered=remove_stopwords(keywords)

#Stemming
ps = PorterStemmer()
keywords_stem = [[ps.stem(word) for word in sentence.split(" ")] for sentence in keywords_filtered]
keywords_stem = [" ".join(sentence) for sentence in keywords_stem]

#Lemmetizing

#POSTags
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

lemmatizer = WordNetLemmatizer()
keywords_lem = [[lemmatizer.lemmatize(y, get_wordnet_pos(y)) for y in sentence.split(" ")] for sentence in keywords_filtered]
keywords_final = [" ".join(sentence) for sentence in keywords_lem]

# %% [markdown]
# ## Fuzzy Matching

# %%
data['final'] = data['final'].apply(str)
choices = data['final'].tolist()

# %%
 def fuzzy_m(row):
        keyword_match, score = process.extractOne(row['final'], keywords_final, scorer = fuzz.partial_ratio)
        row['final_score'] = score
        row['final_keyword_match'] = keyword_match
        return row

# %%
nan_value = float("NaN")
data['final'].replace("", nan_value, inplace=True)
data.dropna(subset = ["final"], inplace=True)

# %%
interim_purp = data.apply(fuzzy_m, axis=1)

# %%
interim_purp
# Out:
#                       user_id  \
# 0                  25610446.0
# 1                  25610446.0
# 2                 189942678.0
# 3                 189942678.0
# 4                 378143915.0
# ...                       ...
# 14440  1.2450977338888847e+18
# 14441              30233254.0
# 14442              22656149.0
# 14443  1.2479186312180326e+18
# 14444            1546639022.0
#
#                                           text_duplicate  \
# 0      @NYGovCuomo for President!\n\n#TrumpIsTheWORST...
# 1      How the government delayed coronavirus testing...
# 2      @ajkatztv @weijia @tvnewser Weijia is the best...
# 3      Stay with @CBSNews on-air and online with cont...
# 4      We are developing muscle memory for the next v...
# ...                                                  ...
# 14440               Caption this https://t.co/lN8jGxOm9J
# 14441  “We have to make sure that all of our equipmen...
# 14442  There’s something bothering Bronx Borough Pres...
# 14443  #SocialDistanacing #Boostmobile @HOTROD276 htt...
# 14444  ...."™Good news, kenneth  allen! ￼ Your electr...
#
#                                                    final  final_score  \
# 0      president trumpistheworstpresidentever trumppr...           50
# 1      the government delayed coronavirus test covid1...           50
# 2      weijia the best at cover the white house come ...           59
# 3      stay onair online continue live coverage the c...           59
# 4      develop muscle memory the next virus covid 19 ...           53
# ...                                                  ...          ...
# 14440                                            caption           43
# 14441  to make sure equipment vehicle cot facility in...           53
# 14442  something bother bronx borough president want ...           53
# 14443                      socialdistanacing boostmobile           41
# 14444  ™good news kenneth allen your electronic stimu...           59
#
#       final_keyword_match
# 0                    save
# 1                    save
# 2       flatten the curve
# 3       flatten the curve
# 4         slow the spread
# ...                   ...
# 14440   flatten the curve
# 14441     slow the spread
# 14442     slow the spread
# 14443   slow transmission
# 14444   slow transmission
#
# [14445 rows x 5 columns]

# %%
denominator = interim_purp.shape[0]

# %%
interim_purp['final_score'] = interim_purp['final_score'].astype(int)

# %%
interim_purp = interim_purp[interim_purp['final_score'] == 100]

# %%
interim_purp
# Out:
#             user_id                                     text_duplicate  \
# 5       733939050.0  Stay vigilant and we can flatten the curve! #F...
# 151      41378381.0  45's economy was a mirage, forced by massive U...
# 188      46039595.0  The City of Huntington Beach closes beachside ...
# 247      33333620.0  Healthcare workers are taping photos of themse...
# 253     399058061.0  Grocery stores ramping up safety to protect cu...
# ...             ...                                                ...
# 14201    25073877.0                           FLATTENING OF THE CURVE!
# 14224    10688432.0  While Gov. Laura Kelly has worked tirelessly f...
# 14232    26113063.0  Friday April 10 1pm EDT Join @ElizabethNgonzi ...
# 14274  2798659231.0  "@ACOG has put amazing things in place to prot...
# 14333   218571357.0  PBOT has partnered with @ridespin to reduce th...
#
#                                                    final  final_score  \
# 5      stay vigilant flatten the curve flattenthecurv...          100
# 151    45s economy mirage force massive u debt amp mi...          100
# 188    the city huntington beach close beachside mete...          100
# 247    healthcare worker tap photo to protective gear...          100
# 253    grocery store ramp safety to protect customer ...          100
# ...                                                  ...          ...
# 14201                                  flatten the curve          100
# 14224  gov laura kelly work tirelessly week to protec...          100
# 14232  friday april 10 1pm edt join the flexibility t...          100
# 14274  put amaze thing place to protect every pregnan...          100
# 14333  pbot partner to reduce the cost escooter renta...          100
#
#       final_keyword_match
# 5       flatten the curve
# 151               protect
# 188       slow the spread
# 247               protect
# 253               protect
# ...                   ...
# 14201   flatten the curve
# 14224             protect
# 14232                save
# 14274             protect
# 14333   stayhomesavelives
#
# [314 rows x 5 columns]

# %%
numerator = interim_purp.shape[0]

# %%
proportion = (numerator/denominator)
print(proportion)
# Out:
# 0.021737625475943233
